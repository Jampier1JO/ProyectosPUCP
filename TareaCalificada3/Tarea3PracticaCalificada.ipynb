# %% [markdown]
# # Tarea Calificada 3

# %% [markdown]
# ## Parte 1

# %%
import pandas as pd

# %%
# Definir la ruta de los archivos en GitHub
append_data_path = 'https://github.com/Jampier1JO/ProyectosPUCP/raw/0a1168b80b6da553a2fa8c20d6575cf78c53131f/TareaCalificada3'

# %%
#Leemos el primer archivo de excel Level1
level1=pd.read_excel(append_data_path+"/level1.xlsx")

# %%
level1
# Out:
#    Unnamed: 0 Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3    HDI rank                                            Country
# 4         NaN                                                NaN
# ..        ...                                                ...
# 67         62                                           Malaysia
# 68         63                                            Georgia
# 69         63                                          Mauritius
# 70         63                                             Serbia
# 71         66                                           Thailand
#
#                         Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                              NaN         NaN                       NaN
# ...

# %%
#Verificamos si hay columnas con valores nulos
level1[level1.isnull().all(axis=1)]
# Out:
#   Unnamed: 0 Table 1. Human Development Index and its components  Unnamed: 2  \
# 0        NaN                                                NaN          NaN
# 2        NaN                                                NaN          NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 2        NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 15
# 0         NaN
# 2         NaN

# %%
#Tomaremos todo el contenido excepto las filas nulas
level1=level1[~level1.isnull().all(axis=1)]
level1.reset_index(drop=True,inplace=True)
level1
# Out:
#    Unnamed: 0 Table 1. Human Development Index and its components   \
# 0         NaN                                                NaN
# 1    HDI rank                                            Country
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4           1                                        Switzerland
# ..        ...                                                ...
# 65         62                                           Malaysia
# 66         63                                            Georgia
# 67         63                                          Mauritius
# 68         63                                             Serbia
# 69         66                                           Thailand
#
#                         Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                              NaN         NaN                      SDG3
# ...

# %%
#Analizando las cabeceras de las columnas notamos un patron y buscamos la forma de limpiar dichas cabeceras
[a for a in zip(level1.iloc[1,:],level1.iloc[2,:],level1.iloc[3,:])]
# Out:
# [('HDI rank', nan, nan),
#  ('Country', nan, nan),
#  ('Human Development Index (HDI) ', 'Value', 2021),
#  (nan, nan, nan),
#  ('Life expectancy at birth', '(years)', 2021),
#  (nan, nan, nan),
#  ('Expected years of schooling', '(years)', 2021),
#  (nan, nan, 'a'),
#  ('Mean years of schooling', '(years)', 2021),
#  (nan, nan, 'a'),
#  ('Gross national income (GNI) per capita', '(2017 PPP $)', 2021),
#  (nan, nan, nan),
#  ('GNI per capita rank minus HDI rank', nan, 2021),
#  (nan, nan, 'b'),
#  ('HDI rank', nan, 2020),
#  (nan, nan, nan)]

# %%
#Juntamos los elementos de la serie en una cadena eliminando la coma que lo separaba
[''.join(map(str, pd.Series(a).dropna())) for a in zip(level1.iloc[1,:], level1.iloc[2,:], level1.iloc[3,:])]
# Out:
# ['HDI rank',
#  'Country',
#  'Human Development Index (HDI) Value2021',
#  '',
#  'Life expectancy at birth(years)2021',
#  '',
#  'Expected years of schooling(years)2021',
#  'a',
#  'Mean years of schooling(years)2021',
#  'a',
#  'Gross national income (GNI) per capita(2017 PPP $)2021',
#  '',
#  'GNI per capita rank minus HDI rank2021',
#  'b',
#  'HDI rank2020',
#  '']

# %%
#Modifico las columnas con la serie de textos hallados anteriormente
level1.columns = [''.join(map(str, pd.Series(a).dropna())) for a in zip(level1.iloc[1, :], level1.iloc[2, :], level1.iloc[3, :])]
#Renombro la columna por comodidades
level1 = level1.rename(columns={'Human Development Index (HDI) Value2021': 'Human Development Index (HDI) 2021'})

# %%
#Visualizo mis nuevas columnas
level1.columns
# Out:
# Index(['HDI rank', 'Country', 'Human Development Index (HDI) 2021', '',
#        'Life expectancy at birth(years)2021', '',
#        'Expected years of schooling(years)2021', 'a',
#        'Mean years of schooling(years)2021', 'a',
#        'Gross national income (GNI) per capita(2017 PPP $)2021', '',
#        'GNI per capita rank minus HDI rank2021', 'b', 'HDI rank2020', ''],
#       dtype='object')

# %%
#Quiero apreciar cuales son las columnas NO vacías
[a for a in level1.columns if len(a)>2]
# Out:
# ['HDI rank',
#  'Country',
#  'Human Development Index (HDI) 2021',
#  'Life expectancy at birth(years)2021',
#  'Expected years of schooling(years)2021',
#  'Mean years of schooling(years)2021',
#  'Gross national income (GNI) per capita(2017 PPP $)2021',
#  'GNI per capita rank minus HDI rank2021',
#  'HDI rank2020']

# %%
#Me quedo solo con las columnas con cabeceras NO vacías, lo actualizo
level1=level1[[a for a in level1.columns if len(a)>2]]
level1.head(10)
# Out:
#    HDI rank                 Country Human Development Index (HDI) 2021  \
# 0       NaN                     NaN                                NaN
# 1  HDI rank                 Country     Human Development Index (HDI)
# 2       NaN                     NaN                              Value
# 3       NaN                     NaN                               2021
# 4         1             Switzerland                              0.962
# 5         2                  Norway                              0.961
# 6         3                 Iceland                              0.959
# 7         4  Hong Kong, China (SAR)                              0.952
# 8         5               Australia                              0.951
# 9         6                 Denmark                              0.948
#
#   Life expectancy at birth(years)2021 Expected years of schooling(years)2021  \
# 0                                SDG3                                 SDG4.3
# ...

# %%
#visualizo las columnas
level1.columns
# Out:
# Index(['HDI rank', 'Country', 'Human Development Index (HDI) 2021',
#        'Life expectancy at birth(years)2021',
#        'Expected years of schooling(years)2021',
#        'Mean years of schooling(years)2021',
#        'Gross national income (GNI) per capita(2017 PPP $)2021',
#        'GNI per capita rank minus HDI rank2021', 'HDI rank2020'],
#       dtype='object')

# %%
#Visualizamos el reemplazo los parentesis y espacios por "_"
level1.columns.str.replace('\(\w*\s*\w*\W*\)','',regex=True).str.title().str.replace("\s","_",regex=True)
# Out:
# Index(['Hdi_Rank', 'Country', 'Human_Development_Index__2021',
#        'Life_Expectancy_At_Birth2021', 'Expected_Years_Of_Schooling2021',
#        'Mean_Years_Of_Schooling2021', 'Gross_National_Income__Per_Capita2021',
#        'Gni_Per_Capita_Rank_Minus_Hdi_Rank2021', 'Hdi_Rank2020'],
#       dtype='object')

# %%
#Reemplazamos los parentesis y espacios por "_"
level1.columns=level1.columns.str.replace('\(\w*\s*\w*\W*\)','',regex=True).str.title().str.replace("\s","_",regex=True)
level1
# Out:
#     Hdi_Rank      Country   Human_Development_Index__2021  \
# 0        NaN          NaN                             NaN
# 1   HDI rank      Country  Human Development Index (HDI)
# 2        NaN          NaN                           Value
# 3        NaN          NaN                            2021
# 4          1  Switzerland                           0.962
# ..       ...          ...                             ...
# 65        62     Malaysia                           0.803
# 66        63      Georgia                           0.802
# 67        63    Mauritius                           0.802
# 68        63       Serbia                           0.802
# 69        66     Thailand                             0.8
#
#    Life_Expectancy_At_Birth2021 Expected_Years_Of_Schooling2021  \
# 0                          SDG3                          SDG4.3
# 1      Life expectancy at birth     Expected years of schooling
# 2                       (years)                         (years)
# ...

# %%
#Hacemos una copia del df y analizamos la existencia de valores nulos
level1_better=level1.copy()
level1_better.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                67 non-null     object
#  1   Country                                 67 non-null     object
#  2   Human_Development_Index__2021           69 non-null     object
#  3   Life_Expectancy_At_Birth2021            70 non-null     object
#  4   Expected_Years_Of_Schooling2021         70 non-null     object
#  5   Mean_Years_Of_Schooling2021             70 non-null     object
#  6   Gross_National_Income__Per_Capita2021   70 non-null     object
#  7   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  68 non-null     object
#  8   Hdi_Rank2020                            68 non-null     object
# dtypes: object(9)
# memory usage: 5.1+ KB

# %%
#Analizamos los valores nulos en la columna "Country"
level1_better[level1_better.Country.isnull()]
# Out:
#   Hdi_Rank Country Human_Development_Index__2021 Life_Expectancy_At_Birth2021  \
# 0      NaN     NaN                           NaN                         SDG3
# 2      NaN     NaN                         Value                      (years)
# 3      NaN     NaN                          2021                         2021
#
#   Expected_Years_Of_Schooling2021 Mean_Years_Of_Schooling2021  \
# 0                          SDG4.3                      SDG4.4
# 2                         (years)                     (years)
# 3                            2021                        2021
#
#   Gross_National_Income__Per_Capita2021  \
# 0                                SDG8.5
# 2                          (2017 PPP $)
# 3                                  2021
#
#   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021 Hdi_Rank2020
# 0                                    NaN          NaN
# 2                                    NaN          NaN
# 3                                   2021         2020

# %%
#Eliminamos las filas con valores nulos en "Country"
level1_better=level1_better[~level1_better.Country.isnull()]
level1_better.reset_index(drop=True, inplace=True)
level1_better
# Out:
#     Hdi_Rank                 Country   Human_Development_Index__2021  \
# 0   HDI rank                 Country  Human Development Index (HDI)
# 1          1             Switzerland                           0.962
# 2          2                  Norway                           0.961
# 3          3                 Iceland                           0.959
# 4          4  Hong Kong, China (SAR)                           0.952
# ..       ...                     ...                             ...
# 62        62                Malaysia                           0.803
# 63        63                 Georgia                           0.802
# 64        63               Mauritius                           0.802
# 65        63                  Serbia                           0.802
# 66        66                Thailand                             0.8
#
#    Life_Expectancy_At_Birth2021 Expected_Years_Of_Schooling2021  \
# 0      Life expectancy at birth     Expected years of schooling
# ...

# %%
#Buscamos valores NO numericos de una fila
level1_better[level1_better.iloc[:, 2].str.contains('\D+').fillna(False)]
# Out:
#    Hdi_Rank  Country   Human_Development_Index__2021  \
# 0  HDI rank  Country  Human Development Index (HDI)
#
#   Life_Expectancy_At_Birth2021 Expected_Years_Of_Schooling2021  \
# 0     Life expectancy at birth     Expected years of schooling
#
#   Mean_Years_Of_Schooling2021   Gross_National_Income__Per_Capita2021  \
# 0     Mean years of schooling  Gross national income (GNI) per capita
#
#   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021 Hdi_Rank2020
# 0     GNI per capita rank minus HDI rank     HDI rank

# %%
#Eliminamos la fila de cadenas
level1_better=level1_better[~level1_better.iloc[:, 2].str.contains('\D+').fillna(False)]
level1_better.reset_index(drop=True, inplace=True)
level1_better
# Out:
#    Hdi_Rank                 Country Human_Development_Index__2021  \
# 0         1             Switzerland                         0.962
# 1         2                  Norway                         0.961
# 2         3                 Iceland                         0.959
# 3         4  Hong Kong, China (SAR)                         0.952
# 4         5               Australia                         0.951
# ..      ...                     ...                           ...
# 61       62                Malaysia                         0.803
# 62       63                 Georgia                         0.802
# 63       63               Mauritius                         0.802
# 64       63                  Serbia                         0.802
# 65       66                Thailand                           0.8
#
#    Life_Expectancy_At_Birth2021 Expected_Years_Of_Schooling2021  \
# 0                       83.9872                       16.500299
# ...

# %%
#Probar si existen valores nulos en la columna "Hdi_Rank"
level1_better[level1_better.Hdi_Rank.isnull()]
# Out:
# Empty DataFrame
# Columns: [Hdi_Rank, Country, Human_Development_Index__2021, Life_Expectancy_At_Birth2021, Expected_Years_Of_Schooling2021, Mean_Years_Of_Schooling2021, Gross_National_Income__Per_Capita2021, Gni_Per_Capita_Rank_Minus_Hdi_Rank2021, Hdi_Rank2020]
# Index: []

# %%
#Ahora validando si existe alguna columna nula
level1_better[level1_better.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Hdi_Rank, Country, Human_Development_Index__2021, Life_Expectancy_At_Birth2021, Expected_Years_Of_Schooling2021, Mean_Years_Of_Schooling2021, Gross_National_Income__Per_Capita2021, Gni_Per_Capita_Rank_Minus_Hdi_Rank2021, Hdi_Rank2020]
# Index: []

# %%
#Validamos la calidad de nuestros datos
level1_better.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                66 non-null     object
#  1   Country                                 66 non-null     object
#  2   Human_Development_Index__2021           66 non-null     object
#  3   Life_Expectancy_At_Birth2021            66 non-null     object
#  4   Expected_Years_Of_Schooling2021         66 non-null     object
#  5   Mean_Years_Of_Schooling2021             66 non-null     object
#  6   Gross_National_Income__Per_Capita2021   66 non-null     object
#  7   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  66 non-null     object
#  8   Hdi_Rank2020                            66 non-null     object
# dtypes: object(9)
# memory usage: 4.8+ KB

# %%
#Evaluamos si los elementos de la columna "Gross_National_Income__Per_Capita2021" son cadenas o textos
level1_better.iloc[:,6]
# Out:
# 0     66933.00454
# 1     64660.10622
# 2     55782.04981
# 3      62606.8454
# 4     49238.43335
#          ...
# 61    26657.94355
# 62    14664.16825
# 63    22025.34631
# 64    19123.02747
# 65    17030.15352
# Name: Gross_National_Income__Per_Capita2021, Length: 66, dtype: object

# %%
#Vamos a transformar todas las columnas en numericos sin afectar a la columna "Country"
level1_clean=level1_better.set_index('Country')
level1_formatted=level1_clean.apply(pd.to_numeric)
level1_formatted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, Switzerland to Thailand
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                66 non-null     int64
#  1   Human_Development_Index__2021           66 non-null     float64
#  2   Life_Expectancy_At_Birth2021            66 non-null     float64
#  3   Expected_Years_Of_Schooling2021         66 non-null     float64
#  4   Mean_Years_Of_Schooling2021             66 non-null     float64
#  5   Gross_National_Income__Per_Capita2021   66 non-null     float64
#  6   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  66 non-null     int64
#  7   Hdi_Rank2020                            66 non-null     int64
# dtypes: float64(5), int64(3)
# memory usage: 4.6+ KB

# %%
#Devolvemos del indice a la columna "Country"
level1_formatted.reset_index(drop=False,inplace=True)
level1_formatted
# Out:
#                    Country  Hdi_Rank  Human_Development_Index__2021  \
# 0              Switzerland         1                          0.962
# 1                   Norway         2                          0.961
# 2                  Iceland         3                          0.959
# 3   Hong Kong, China (SAR)         4                          0.952
# 4                Australia         5                          0.951
# ..                     ...       ...                            ...
# 61                Malaysia        62                          0.803
# 62                 Georgia        63                          0.802
# 63               Mauritius        63                          0.802
# 64                  Serbia        63                          0.802
# 65                Thailand        66                          0.800
#
#     Life_Expectancy_At_Birth2021  Expected_Years_Of_Schooling2021  \
# 0                        83.9872                        16.500299
# ...

# %%
#Colocamos en mayuscula los elementos de la columna "Country"
level1_formatted['Country']=level1_formatted.Country.str.strip()
level1_formatted['Country']=level1_formatted.Country.str.upper()
level1_formatted
# Out:
#                    Country  Hdi_Rank  Human_Development_Index__2021  \
# 0              SWITZERLAND         1                          0.962
# 1                   NORWAY         2                          0.961
# 2                  ICELAND         3                          0.959
# 3   HONG KONG, CHINA (SAR)         4                          0.952
# 4                AUSTRALIA         5                          0.951
# ..                     ...       ...                            ...
# 61                MALAYSIA        62                          0.803
# 62                 GEORGIA        63                          0.802
# 63               MAURITIUS        63                          0.802
# 64                  SERBIA        63                          0.802
# 65                THAILAND        66                          0.800
#
#     Life_Expectancy_At_Birth2021  Expected_Years_Of_Schooling2021  \
# 0                        83.9872                        16.500299
# ...

# %%
#Agregamos la columna de indicador de desarrollo
level1_formatted['Development'] = "VERY HIGH HUMAN DEVELOPMENT"
level1_formatted
# Out:
#                    Country  Hdi_Rank  Human_Development_Index__2021  \
# 0              SWITZERLAND         1                          0.962
# 1                   NORWAY         2                          0.961
# 2                  ICELAND         3                          0.959
# 3   HONG KONG, CHINA (SAR)         4                          0.952
# 4                AUSTRALIA         5                          0.951
# ..                     ...       ...                            ...
# 61                MALAYSIA        62                          0.803
# 62                 GEORGIA        63                          0.802
# 63               MAURITIUS        63                          0.802
# 64                  SERBIA        63                          0.802
# 65                THAILAND        66                          0.800
#
#     Life_Expectancy_At_Birth2021  Expected_Years_Of_Schooling2021  \
# 0                        83.9872                        16.500299
# ...

# %%
#Leemos el segundo archivo de excel Level2
level2=pd.read_excel(append_data_path+"/level2.xlsx")

# %%
level2
# Out:
#     HDI rank                           Country  \
# 0        NaN                               NaN
# 1        NaN            HIGH HUMAN DEVELOPMENT
# 2       67.0                           Albania
# 3       68.0                          Bulgaria
# 4       68.0                           Grenada
# 5       70.0                          Barbados
# 6       71.0               Antigua and Barbuda
# 7       72.0                        Seychelles
# 8       73.0                         Sri Lanka
# 9       74.0            Bosnia and Herzegovina
# 10      75.0             Saint Kitts and Nevis
# 11      76.0        Iran (Islamic Republic of)
# 12      77.0                           Ukraine
# 13      78.0                   North Macedonia
# 14      79.0                             China
# 15      80.0                Dominican Republic
# 16      80.0             Moldova (Republic of)
# 17      80.0                             Palau
# 18      83.0                              Cuba
# ...

# %%
#Analizamos la tabla y notamos que las cabeceras "Unnamed" no aportan informacion
level2 = level2.loc[:, ~level2.columns.str.startswith('Unnamed')]

# %%
#Verificamos si hay columnas con valores nulos
level2[level2.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [HDI rank, Country, Human Development Index (HDI) , Life expectancy at birth, Expected years of schooling, Mean years of schooling, Gross national income (GNI) per capita, GNI per capita rank minus HDI rank, HDI rank.1]
# Index: []

# %%
#Convertir las cabeceras en la primera fila
level2.loc[-1] = level2.columns  # Añadir las cabeceras como la primera fila
level2.index = level2.index + 1  # Desplazar los índices hacia abajo
level2 = level2.sort_index()  # Ordenar por índice

#Eliminar las cabeceras
level2.columns = range(level2.shape[1])
level2
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4620\870654628.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   level2.loc[-1] = level2.columns  # Añadir las cabeceras como la primera fila
#            0                                 1  \
# 0   HDI rank                           Country
# 1        NaN                               NaN
# 2        NaN            HIGH HUMAN DEVELOPMENT
# 3       67.0                           Albania
# 4       68.0                          Bulgaria
# 5       68.0                           Grenada
# 6       70.0                          Barbados
# 7       71.0               Antigua and Barbuda
# 8       72.0                        Seychelles
# 9       73.0                         Sri Lanka
# 10      74.0            Bosnia and Herzegovina
# ...

# %%
#Analizando las cabeceras de las columnas notamos un patron y buscamos la forma de limpiar dichas cabeceras
[a for a in zip(level2.iloc[0,:],level2.iloc[1,:])]
# Out:
# [('HDI rank', nan),
#  ('Country', nan),
#  ('Human Development Index (HDI) ', 2021.0),
#  ('Life expectancy at birth', 2021.0),
#  ('Expected years of schooling', 2021.0),
#  ('Mean years of schooling', 2021.0),
#  ('Gross national income (GNI) per capita', 2021.0),
#  ('GNI per capita rank minus HDI rank', 2021.0),
#  ('HDI rank.1', 2020.0)]

# %%
#Juntamos los elementos de la serie en una cadena eliminando la coma que lo separaba
[''.join(map(lambda x: str(int(x)) if pd.notnull(x) and isinstance(x, float) and x.is_integer() else str(x), pd.Series(a).dropna())) for a in zip(level2.iloc[0,:], level2.iloc[1,:])]
# Out:
# ['HDI rank',
#  'Country',
#  'Human Development Index (HDI) 2021',
#  'Life expectancy at birth2021',
#  'Expected years of schooling2021',
#  'Mean years of schooling2021',
#  'Gross national income (GNI) per capita2021',
#  'GNI per capita rank minus HDI rank2021',
#  'HDI rank.12020']

# %%
#Modifico las columnas con la serie de textos hallados anteriormente
level2.columns = [''.join(map(lambda x: str(int(x)) if pd.notnull(x) and isinstance(x, float) and x.is_integer() else str(x), pd.Series(a).dropna())) for a in zip(level2.iloc[0,:], level2.iloc[1,:])]
#Renombro la columna por comodidades
level2 = level2.rename(columns={'HDI rank.12020': 'HDI rank2020'})

# %%
#Visualizo mis nuevas columnas
level2.columns
# Out:
# Index(['HDI rank', 'Country', 'Human Development Index (HDI) 2021',
#        'Life expectancy at birth2021', 'Expected years of schooling2021',
#        'Mean years of schooling2021',
#        'Gross national income (GNI) per capita2021',
#        'GNI per capita rank minus HDI rank2021', 'HDI rank2020'],
#       dtype='object')

# %%
#Visualizamos el reemplazo los parentesis y espacios por "_"
level2.columns.str.replace('\(\w*\s*\w*\W*\)','',regex=True).str.title().str.replace("\s","_",regex=True)
# Out:
# Index(['Hdi_Rank', 'Country', 'Human_Development_Index__2021',
#        'Life_Expectancy_At_Birth2021', 'Expected_Years_Of_Schooling2021',
#        'Mean_Years_Of_Schooling2021', 'Gross_National_Income__Per_Capita2021',
#        'Gni_Per_Capita_Rank_Minus_Hdi_Rank2021', 'Hdi_Rank2020'],
#       dtype='object')

# %%
#Reemplazamos los parentesis y espacios por "_"
level2.columns=level2.columns.str.replace('\(\w*\s*\w*\W*\)','',regex=True).str.title().str.replace("\s","_",regex=True)
level2
# Out:
#     Hdi_Rank                           Country  \
# 0   HDI rank                           Country
# 1        NaN                               NaN
# 2        NaN            HIGH HUMAN DEVELOPMENT
# 3       67.0                           Albania
# 4       68.0                          Bulgaria
# 5       68.0                           Grenada
# 6       70.0                          Barbados
# 7       71.0               Antigua and Barbuda
# 8       72.0                        Seychelles
# 9       73.0                         Sri Lanka
# 10      74.0            Bosnia and Herzegovina
# 11      75.0             Saint Kitts and Nevis
# 12      76.0        Iran (Islamic Republic of)
# 13      77.0                           Ukraine
# 14      78.0                   North Macedonia
# 15      79.0                             China
# 16      80.0                Dominican Republic
# 17      80.0             Moldova (Republic of)
# 18      80.0                             Palau
# ...

# %%
#Hacemos una copia del df y analizamos la existencia de valores nulos
level2_better=level2.copy()
level2_better.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                50 non-null     object
#  1   Country                                 51 non-null     object
#  2   Human_Development_Index__2021           51 non-null     object
#  3   Life_Expectancy_At_Birth2021            51 non-null     object
#  4   Expected_Years_Of_Schooling2021         51 non-null     object
#  5   Mean_Years_Of_Schooling2021             51 non-null     object
#  6   Gross_National_Income__Per_Capita2021   51 non-null     object
#  7   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  51 non-null     object
#  8   Hdi_Rank2020                            51 non-null     object
# dtypes: object(9)
# memory usage: 4.1+ KB

# %%
#Analizamos los valores nulos en las columnas 1:3
level2_better[level2_better.iloc[:,1:3].isnull().any(axis=1)]
# Out:
#   Hdi_Rank                 Country Human_Development_Index__2021  \
# 1      NaN                     NaN                        2021.0
# 2      NaN  HIGH HUMAN DEVELOPMENT                           NaN
#
#   Life_Expectancy_At_Birth2021 Expected_Years_Of_Schooling2021  \
# 1                       2021.0                          2021.0
# 2                          NaN                             NaN
#
#   Mean_Years_Of_Schooling2021 Gross_National_Income__Per_Capita2021  \
# 1                      2021.0                                2021.0
# 2                         NaN                                   NaN
#
#   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021 Hdi_Rank2020
# 1                                 2021.0       2020.0
# 2                                    NaN          NaN

# %%
#Eliminamos las filas con valores nulos en las columnas 1:3
level2_better=level2_better[~level2_better.iloc[:,1:3].isnull().any(axis=1)]
level2_better.reset_index(drop=True, inplace=True)
level2_better
# Out:
#     Hdi_Rank                           Country  \
# 0   HDI rank                           Country
# 1       67.0                           Albania
# 2       68.0                          Bulgaria
# 3       68.0                           Grenada
# 4       70.0                          Barbados
# 5       71.0               Antigua and Barbuda
# 6       72.0                        Seychelles
# 7       73.0                         Sri Lanka
# 8       74.0            Bosnia and Herzegovina
# 9       75.0             Saint Kitts and Nevis
# 10      76.0        Iran (Islamic Republic of)
# 11      77.0                           Ukraine
# 12      78.0                   North Macedonia
# 13      79.0                             China
# 14      80.0                Dominican Republic
# 15      80.0             Moldova (Republic of)
# 16      80.0                             Palau
# 17      83.0                              Cuba
# 18      84.0                              Peru
# ...

# %%
#Buscamos valores NO numericos de una fila
level2_better[level2_better.iloc[:, 2].str.contains('\D+').fillna(False)]
# Out:
#    Hdi_Rank  Country   Human_Development_Index__2021  \
# 0  HDI rank  Country  Human Development Index (HDI)
#
#   Life_Expectancy_At_Birth2021 Expected_Years_Of_Schooling2021  \
# 0     Life expectancy at birth     Expected years of schooling
#
#   Mean_Years_Of_Schooling2021   Gross_National_Income__Per_Capita2021  \
# 0     Mean years of schooling  Gross national income (GNI) per capita
#
#   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021 Hdi_Rank2020
# 0     GNI per capita rank minus HDI rank   HDI rank.1

# %%
#Eliminamos la fila de cadenas
level2_better=level2_better[~level2_better.iloc[:, 2].str.contains('\D+').fillna(False)]
level2_better.reset_index(drop=True, inplace=True)
level2_better
# Out:
#    Hdi_Rank                           Country Human_Development_Index__2021  \
# 0      67.0                           Albania                         0.796
# 1      68.0                          Bulgaria                         0.795
# 2      68.0                           Grenada                         0.795
# 3      70.0                          Barbados                          0.79
# 4      71.0               Antigua and Barbuda                         0.788
# 5      72.0                        Seychelles                         0.785
# 6      73.0                         Sri Lanka                         0.782
# 7      74.0            Bosnia and Herzegovina                          0.78
# 8      75.0             Saint Kitts and Nevis                         0.777
# 9      76.0        Iran (Islamic Republic of)                         0.774
# 10     77.0                           Ukraine                         0.773
# ...

# %%
#Probar si existen valores nulos en la columna "Hdi_Rank"
level2_better[level2_better.Hdi_Rank.isnull()]
# Out:
# Empty DataFrame
# Columns: [Hdi_Rank, Country, Human_Development_Index__2021, Life_Expectancy_At_Birth2021, Expected_Years_Of_Schooling2021, Mean_Years_Of_Schooling2021, Gross_National_Income__Per_Capita2021, Gni_Per_Capita_Rank_Minus_Hdi_Rank2021, Hdi_Rank2020]
# Index: []

# %%
#Ahora validando si existe alguna columna nula
level2_better[level2_better.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Hdi_Rank, Country, Human_Development_Index__2021, Life_Expectancy_At_Birth2021, Expected_Years_Of_Schooling2021, Mean_Years_Of_Schooling2021, Gross_National_Income__Per_Capita2021, Gni_Per_Capita_Rank_Minus_Hdi_Rank2021, Hdi_Rank2020]
# Index: []

# %%
#Validamos la calidad de nuestros datos
level2_better.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                49 non-null     object
#  1   Country                                 49 non-null     object
#  2   Human_Development_Index__2021           49 non-null     object
#  3   Life_Expectancy_At_Birth2021            49 non-null     object
#  4   Expected_Years_Of_Schooling2021         49 non-null     object
#  5   Mean_Years_Of_Schooling2021             49 non-null     object
#  6   Gross_National_Income__Per_Capita2021   49 non-null     object
#  7   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  49 non-null     object
#  8   Hdi_Rank2020                            49 non-null     object
# dtypes: object(9)
# memory usage: 3.6+ KB

# %%
#Evaluamos si los elementos de la columna "Gross_National_Income__Per_Capita2021" son cadenas o textos
level2_better.iloc[:,6]
# Out:
# 0     14131.11039
# 1     23078.95595
# 2      13483.5774
# 3       12306.341
# 4     16792.36595
# 5     25830.61775
# 6     12578.22055
# 7     15241.91465
# 8     23358.33212
# 9      13000.7117
# 10    13255.50977
# 11    15917.75283
# 12    17504.39969
# 13    17989.60037
# 14    14875.33189
# 15    13818.67869
# 16    7878.847482
# 17    12245.89366
# 18     13157.9939
# 19    17896.29498
# 20    14369.88848
# 21    14384.35666
# 22    11961.08792
# 23    15448.12788
# 24    10800.22546
# 25    14256.74456
# 26     6822.03125
# 27     13020.7155
# 28    10311.63273
# 29    10588.22532
# 30    11731.69056
# 31    10257.54477
# 32    9980.110866
# 33    12672.20033
# 34    7916.785725
# 35    11487.62422
# 36    9923.714974
# 37      15335.712
# 38      12349.286
# 39    6582.899416
# 40    12048.30381
# 41    22464.65734
# 42    12948.37325
# 43     8834.47567
# 44    5307.953374
# 45    13366.93455
# 46    9525.831467
# 47    11466.06836
# 48    7867.371345
# ...

# %%
#Vamos a transformar todas las columnas en numericos sin afectar a la columna "Country"
level2_clean=level2_better.set_index('Country')
level2_formatted=level2_clean.apply(pd.to_numeric)
level2_formatted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Albania to Viet Nam
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                49 non-null     float64
#  1   Human_Development_Index__2021           49 non-null     float64
#  2   Life_Expectancy_At_Birth2021            49 non-null     float64
#  3   Expected_Years_Of_Schooling2021         49 non-null     float64
#  4   Mean_Years_Of_Schooling2021             49 non-null     float64
#  5   Gross_National_Income__Per_Capita2021   49 non-null     float64
#  6   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  49 non-null     float64
#  7   Hdi_Rank2020                            49 non-null     float64
# dtypes: float64(8)
# memory usage: 3.4+ KB

# %%
#Devolvemos del indice a la columna "Country"
level2_formatted.reset_index(drop=False,inplace=True)
level2_formatted
# Out:
#                              Country  Hdi_Rank  Human_Development_Index__2021  \
# 0                            Albania      67.0                          0.796
# 1                           Bulgaria      68.0                          0.795
# 2                            Grenada      68.0                          0.795
# 3                           Barbados      70.0                          0.790
# 4                Antigua and Barbuda      71.0                          0.788
# 5                         Seychelles      72.0                          0.785
# 6                          Sri Lanka      73.0                          0.782
# 7             Bosnia and Herzegovina      74.0                          0.780
# 8              Saint Kitts and Nevis      75.0                          0.777
# 9         Iran (Islamic Republic of)      76.0                          0.774
# 10                           Ukraine      77.0                          0.773
# ...

# %%
#Colocamos en mayuscula los elementos de la columna "Country"
level2_formatted['Country']=level2_formatted.Country.str.strip()
level2_formatted['Country']=level2_formatted.Country.str.upper()
level2_formatted
# Out:
#                              Country  Hdi_Rank  Human_Development_Index__2021  \
# 0                            ALBANIA      67.0                          0.796
# 1                           BULGARIA      68.0                          0.795
# 2                            GRENADA      68.0                          0.795
# 3                           BARBADOS      70.0                          0.790
# 4                ANTIGUA AND BARBUDA      71.0                          0.788
# 5                         SEYCHELLES      72.0                          0.785
# 6                          SRI LANKA      73.0                          0.782
# 7             BOSNIA AND HERZEGOVINA      74.0                          0.780
# 8              SAINT KITTS AND NEVIS      75.0                          0.777
# 9         IRAN (ISLAMIC REPUBLIC OF)      76.0                          0.774
# 10                           UKRAINE      77.0                          0.773
# ...

# %%
#Agregamos la columna de indicador de desarrollo
level2_formatted['Development'] = "HIGH HUMAN DEVELOPMENT"
level2_formatted
# Out:
#                              Country  Hdi_Rank  Human_Development_Index__2021  \
# 0                            ALBANIA      67.0                          0.796
# 1                           BULGARIA      68.0                          0.795
# 2                            GRENADA      68.0                          0.795
# 3                           BARBADOS      70.0                          0.790
# 4                ANTIGUA AND BARBUDA      71.0                          0.788
# 5                         SEYCHELLES      72.0                          0.785
# 6                          SRI LANKA      73.0                          0.782
# 7             BOSNIA AND HERZEGOVINA      74.0                          0.780
# 8              SAINT KITTS AND NEVIS      75.0                          0.777
# 9         IRAN (ISLAMIC REPUBLIC OF)      76.0                          0.774
# 10                           UKRAINE      77.0                          0.773
# ...

# %%
#Leemos el tercer archivo de excel Level3
level3=pd.read_excel(append_data_path+"/level3.xlsx")

# %%
level3
# Out:
#     HDI rank                             Country  \
# 0        NaN                                 NaN
# 1        NaN            MEDIUM HUMAN DEVELOPMENT
# 2      116.0                         Philippines
# 3      117.0                            Botswana
# 4      118.0    Bolivia (Plurinational State of)
# 5      118.0                          Kyrgyzstan
# 6      120.0  Venezuela (Bolivarian Republic of)
# 7      121.0                                Iraq
# 8      122.0                          Tajikistan
# 9      123.0                              Belize
# 10     123.0                             Morocco
# 11     125.0                         El Salvador
# 12     126.0                           Nicaragua
# 13     127.0                              Bhutan
# 14     128.0                          Cabo Verde
# 15     129.0                          Bangladesh
# 16     130.0                              Tuvalu
# 17     131.0                    Marshall Islands
# ...

# %%
#Analizamos la tabla y notamos que las cabeceras "Unnamed" no aportan informacion
level3 = level3.loc[:, ~level3.columns.str.startswith('Unnamed')]

# %%
#Verificamos si hay columnas con valores nulos
level3[level3.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [HDI rank, Country, Human Development Index (HDI) , Life expectancy at birth, Expected years of schooling, Mean years of schooling, Gross national income (GNI) per capita, GNI per capita rank minus HDI rank, HDI rank.1]
# Index: []

# %%
#Convertir las cabeceras en la primera fila
level3.loc[-1] = level3.columns  # Añadir las cabeceras como la primera fila
level3.index = level3.index + 1  # Desplazar los índices hacia abajo
level3 = level3.sort_index()  # Ordenar por índice

#Eliminar las cabeceras
level3.columns = range(level3.shape[1])
level3
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4620\712585666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   level3.loc[-1] = level3.columns  # Añadir las cabeceras como la primera fila
#            0                                   1  \
# 0   HDI rank                             Country
# 1        NaN                                 NaN
# 2        NaN            MEDIUM HUMAN DEVELOPMENT
# 3      116.0                         Philippines
# 4      117.0                            Botswana
# 5      118.0    Bolivia (Plurinational State of)
# 6      118.0                          Kyrgyzstan
# 7      120.0  Venezuela (Bolivarian Republic of)
# 8      121.0                                Iraq
# 9      122.0                          Tajikistan
# 10     123.0                              Belize
# ...

# %%
#Analizando las cabeceras de las columnas notamos un patron y buscamos la forma de limpiar dichas cabeceras
[a for a in zip(level3.iloc[0,:],level3.iloc[1,:])]
# Out:
# [('HDI rank', nan),
#  ('Country', nan),
#  ('Human Development Index (HDI) ', 2021.0),
#  ('Life expectancy at birth', 2021.0),
#  ('Expected years of schooling', 2021.0),
#  ('Mean years of schooling', 2021.0),
#  ('Gross national income (GNI) per capita', 2021.0),
#  ('GNI per capita rank minus HDI rank', 2021.0),
#  ('HDI rank.1', 2020.0)]

# %%
#Juntamos los elementos de la serie en una cadena eliminando la coma que lo separaba
[''.join(map(lambda x: str(int(x)) if pd.notnull(x) and isinstance(x, float) and x.is_integer() else str(x), pd.Series(a).dropna())) for a in zip(level3.iloc[0,:], level3.iloc[1,:])]
# Out:
# ['HDI rank',
#  'Country',
#  'Human Development Index (HDI) 2021',
#  'Life expectancy at birth2021',
#  'Expected years of schooling2021',
#  'Mean years of schooling2021',
#  'Gross national income (GNI) per capita2021',
#  'GNI per capita rank minus HDI rank2021',
#  'HDI rank.12020']

# %%
#Modifico las columnas con la serie de textos hallados anteriormente
level3.columns = [''.join(map(lambda x: str(int(x)) if pd.notnull(x) and isinstance(x, float) and x.is_integer() else str(x), pd.Series(a).dropna())) for a in zip(level3.iloc[0,:], level3.iloc[1,:])]
#Renombro la columna por comodidades
level3 = level3.rename(columns={'HDI rank.12020': 'HDI rank2020'})

# %%
#Visualizo mis nuevas columnas
level3.columns
# Out:
# Index(['HDI rank', 'Country', 'Human Development Index (HDI) 2021',
#        'Life expectancy at birth2021', 'Expected years of schooling2021',
#        'Mean years of schooling2021',
#        'Gross national income (GNI) per capita2021',
#        'GNI per capita rank minus HDI rank2021', 'HDI rank2020'],
#       dtype='object')

# %%
#Visualizamos el reemplazo los parentesis y espacios por "_"
level3.columns.str.replace('\(\w*\s*\w*\W*\)','',regex=True).str.title().str.replace("\s","_",regex=True)
# Out:
# Index(['Hdi_Rank', 'Country', 'Human_Development_Index__2021',
#        'Life_Expectancy_At_Birth2021', 'Expected_Years_Of_Schooling2021',
#        'Mean_Years_Of_Schooling2021', 'Gross_National_Income__Per_Capita2021',
#        'Gni_Per_Capita_Rank_Minus_Hdi_Rank2021', 'Hdi_Rank2020'],
#       dtype='object')

# %%
#Reemplazamos los parentesis y espacios por "_"
level3.columns=level3.columns.str.replace('\(\w*\s*\w*\W*\)','',regex=True).str.title().str.replace("\s","_",regex=True)
level3
# Out:
#     Hdi_Rank                             Country  \
# 0   HDI rank                             Country
# 1        NaN                                 NaN
# 2        NaN            MEDIUM HUMAN DEVELOPMENT
# 3      116.0                         Philippines
# 4      117.0                            Botswana
# 5      118.0    Bolivia (Plurinational State of)
# 6      118.0                          Kyrgyzstan
# 7      120.0  Venezuela (Bolivarian Republic of)
# 8      121.0                                Iraq
# 9      122.0                          Tajikistan
# 10     123.0                              Belize
# 11     123.0                             Morocco
# 12     125.0                         El Salvador
# 13     126.0                           Nicaragua
# 14     127.0                              Bhutan
# 15     128.0                          Cabo Verde
# 16     129.0                          Bangladesh
# 17     130.0                              Tuvalu
# ...

# %%
#Hacemos una copia del df y analizamos la existencia de valores nulos
level3_better=level3.copy()
level3_better.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                45 non-null     object
#  1   Country                                 46 non-null     object
#  2   Human_Development_Index__2021           46 non-null     object
#  3   Life_Expectancy_At_Birth2021            46 non-null     object
#  4   Expected_Years_Of_Schooling2021         46 non-null     object
#  5   Mean_Years_Of_Schooling2021             46 non-null     object
#  6   Gross_National_Income__Per_Capita2021   46 non-null     object
#  7   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  46 non-null     object
#  8   Hdi_Rank2020                            46 non-null     object
# dtypes: object(9)
# memory usage: 3.7+ KB

# %%
#Analizamos los valores nulos en las columnas 1:3
level3_better[level3_better.iloc[:,1:3].isnull().any(axis=1)]
# Out:
#   Hdi_Rank                   Country Human_Development_Index__2021  \
# 1      NaN                       NaN                        2021.0
# 2      NaN  MEDIUM HUMAN DEVELOPMENT                           NaN
#
#   Life_Expectancy_At_Birth2021 Expected_Years_Of_Schooling2021  \
# 1                       2021.0                          2021.0
# 2                          NaN                             NaN
#
#   Mean_Years_Of_Schooling2021 Gross_National_Income__Per_Capita2021  \
# 1                      2021.0                                2021.0
# 2                         NaN                                   NaN
#
#   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021 Hdi_Rank2020
# 1                                 2021.0       2020.0
# 2                                    NaN          NaN

# %%
#Eliminamos las filas con valores nulos en las columnas 1:3
level3_better=level3_better[~level3_better.iloc[:,1:3].isnull().any(axis=1)]
level3_better.reset_index(drop=True, inplace=True)
level3_better
# Out:
#     Hdi_Rank                             Country  \
# 0   HDI rank                             Country
# 1      116.0                         Philippines
# 2      117.0                            Botswana
# 3      118.0    Bolivia (Plurinational State of)
# 4      118.0                          Kyrgyzstan
# 5      120.0  Venezuela (Bolivarian Republic of)
# 6      121.0                                Iraq
# 7      122.0                          Tajikistan
# 8      123.0                              Belize
# 9      123.0                             Morocco
# 10     125.0                         El Salvador
# 11     126.0                           Nicaragua
# 12     127.0                              Bhutan
# 13     128.0                          Cabo Verde
# 14     129.0                          Bangladesh
# 15     130.0                              Tuvalu
# 16     131.0                    Marshall Islands
# 17     132.0                               India
# ...

# %%
#Buscamos valores NO numericos de una fila
level3_better[level3_better.iloc[:, 2].str.contains('\D+').fillna(False)]
# Out:
#    Hdi_Rank  Country   Human_Development_Index__2021  \
# 0  HDI rank  Country  Human Development Index (HDI)
#
#   Life_Expectancy_At_Birth2021 Expected_Years_Of_Schooling2021  \
# 0     Life expectancy at birth     Expected years of schooling
#
#   Mean_Years_Of_Schooling2021   Gross_National_Income__Per_Capita2021  \
# 0     Mean years of schooling  Gross national income (GNI) per capita
#
#   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021 Hdi_Rank2020
# 0     GNI per capita rank minus HDI rank   HDI rank.1

# %%
#Eliminamos la fila de cadenas
level3_better=level3_better[~level3_better.iloc[:, 2].str.contains('\D+').fillna(False)]
level3_better.reset_index(drop=True, inplace=True)
level3_better
# Out:
#    Hdi_Rank                             Country Human_Development_Index__2021  \
# 0     116.0                         Philippines                         0.699
# 1     117.0                            Botswana                         0.693
# 2     118.0    Bolivia (Plurinational State of)                         0.692
# 3     118.0                          Kyrgyzstan                         0.692
# 4     120.0  Venezuela (Bolivarian Republic of)                         0.691
# 5     121.0                                Iraq                         0.686
# 6     122.0                          Tajikistan                         0.685
# 7     123.0                              Belize                         0.683
# 8     123.0                             Morocco                         0.683
# 9     125.0                         El Salvador                         0.675
# 10    126.0                           Nicaragua                         0.667
# ...

# %%
#Probar si existen valores nulos en la columna "Hdi_Rank"
level3_better[level3_better.Hdi_Rank.isnull()]
# Out:
# Empty DataFrame
# Columns: [Hdi_Rank, Country, Human_Development_Index__2021, Life_Expectancy_At_Birth2021, Expected_Years_Of_Schooling2021, Mean_Years_Of_Schooling2021, Gross_National_Income__Per_Capita2021, Gni_Per_Capita_Rank_Minus_Hdi_Rank2021, Hdi_Rank2020]
# Index: []

# %%
#Ahora validando si existe alguna columna nula
level3_better[level3_better.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Hdi_Rank, Country, Human_Development_Index__2021, Life_Expectancy_At_Birth2021, Expected_Years_Of_Schooling2021, Mean_Years_Of_Schooling2021, Gross_National_Income__Per_Capita2021, Gni_Per_Capita_Rank_Minus_Hdi_Rank2021, Hdi_Rank2020]
# Index: []

# %%
#Validamos la calidad de nuestros datos
level3_better.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                44 non-null     object
#  1   Country                                 44 non-null     object
#  2   Human_Development_Index__2021           44 non-null     object
#  3   Life_Expectancy_At_Birth2021            44 non-null     object
#  4   Expected_Years_Of_Schooling2021         44 non-null     object
#  5   Mean_Years_Of_Schooling2021             44 non-null     object
#  6   Gross_National_Income__Per_Capita2021   44 non-null     object
#  7   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  44 non-null     object
#  8   Hdi_Rank2020                            44 non-null     object
# dtypes: object(9)
# memory usage: 3.2+ KB

# %%
#Evaluamos si los elementos de la columna "Gross_National_Income__Per_Capita2021" son cadenas o textos
level3_better.iloc[:,6]
# Out:
# 0     8920.428468
# 1     16198.31841
# 2     8111.190194
# 3     4566.303831
# 4     4810.882621
# 5     9977.249073
# 6     4547.742427
# 7     6309.099778
# 8      7302.81917
# 9     8295.665889
# 10    5624.793595
# 11    9437.541512
# 12    6230.200199
# 13    5472.104781
# 14    6351.435899
# 15    4619.535393
# 16    6589.980037
# 17    5744.504017
# 18    3696.173945
# 19    8723.285317
# 20    4062.586034
# 21    5297.955301
# 22    4021.350815
# 23    8633.504452
# 24    7699.579617
# 25    4460.869435
# 26    3085.411633
# 27    3877.315444
# 28    7678.591873
# 29    12073.95993
# 30    4078.697154
# 31    3809.887158
# 32    5465.617791
# 33    3850.524234
# 34    4191.933893
# 35    3620.932408
# 36    4473.570344
# 37    2889.283521
# 38    3217.767739
# 39    2481.511362
# 40    3142.064119
# 41    4008.623573
# 42    5075.305711
# 43    5217.448516
# Name: Gross_National_Income__Per_Capita2021, dtype: object

# %%
#Vamos a transformar todas las columnas en numericos sin afectar a la columna "Country"
level3_clean=level3_better.set_index('Country')
level3_formatted=level3_clean.apply(pd.to_numeric)
level3_formatted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, Philippines to Côte d'Ivoire
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                44 non-null     float64
#  1   Human_Development_Index__2021           44 non-null     float64
#  2   Life_Expectancy_At_Birth2021            44 non-null     float64
#  3   Expected_Years_Of_Schooling2021         44 non-null     float64
#  4   Mean_Years_Of_Schooling2021             44 non-null     float64
#  5   Gross_National_Income__Per_Capita2021   44 non-null     float64
#  6   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  44 non-null     float64
#  7   Hdi_Rank2020                            44 non-null     float64
# dtypes: float64(8)
# memory usage: 3.1+ KB

# %%
#Devolvemos del indice a la columna "Country"
level3_formatted.reset_index(drop=False,inplace=True)
level3_formatted
# Out:
#                                Country  Hdi_Rank  \
# 0                          Philippines     116.0
# 1                             Botswana     117.0
# 2     Bolivia (Plurinational State of)     118.0
# 3                           Kyrgyzstan     118.0
# 4   Venezuela (Bolivarian Republic of)     120.0
# 5                                 Iraq     121.0
# 6                           Tajikistan     122.0
# 7                               Belize     123.0
# 8                              Morocco     123.0
# 9                          El Salvador     125.0
# 10                           Nicaragua     126.0
# 11                              Bhutan     127.0
# 12                          Cabo Verde     128.0
# 13                          Bangladesh     129.0
# 14                              Tuvalu     130.0
# 15                    Marshall Islands     131.0
# 16                               India     132.0
# 17                               Ghana     133.0
# ...

# %%
#Colocamos en mayuscula los elementos de la columna "Country"
level3_formatted['Country']=level3_formatted.Country.str.strip()
level3_formatted['Country']=level3_formatted.Country.str.upper()
level3_formatted
# Out:
#                                Country  Hdi_Rank  \
# 0                          PHILIPPINES     116.0
# 1                             BOTSWANA     117.0
# 2     BOLIVIA (PLURINATIONAL STATE OF)     118.0
# 3                           KYRGYZSTAN     118.0
# 4   VENEZUELA (BOLIVARIAN REPUBLIC OF)     120.0
# 5                                 IRAQ     121.0
# 6                           TAJIKISTAN     122.0
# 7                               BELIZE     123.0
# 8                              MOROCCO     123.0
# 9                          EL SALVADOR     125.0
# 10                           NICARAGUA     126.0
# 11                              BHUTAN     127.0
# 12                          CABO VERDE     128.0
# 13                          BANGLADESH     129.0
# 14                              TUVALU     130.0
# 15                    MARSHALL ISLANDS     131.0
# 16                               INDIA     132.0
# 17                               GHANA     133.0
# ...

# %%
#Agregamos la columna de indicador de desarrollo
level3_formatted['Development'] = "MEDIUM HUMAN DEVELOPMENT"
level3_formatted
# Out:
#                                Country  Hdi_Rank  \
# 0                          PHILIPPINES     116.0
# 1                             BOTSWANA     117.0
# 2     BOLIVIA (PLURINATIONAL STATE OF)     118.0
# 3                           KYRGYZSTAN     118.0
# 4   VENEZUELA (BOLIVARIAN REPUBLIC OF)     120.0
# 5                                 IRAQ     121.0
# 6                           TAJIKISTAN     122.0
# 7                               BELIZE     123.0
# 8                              MOROCCO     123.0
# 9                          EL SALVADOR     125.0
# 10                           NICARAGUA     126.0
# 11                              BHUTAN     127.0
# 12                          CABO VERDE     128.0
# 13                          BANGLADESH     129.0
# 14                              TUVALU     130.0
# 15                    MARSHALL ISLANDS     131.0
# 16                               INDIA     132.0
# 17                               GHANA     133.0
# ...

# %%
#Leemos el cuarto archivo de excel Level4
level4=pd.read_excel(append_data_path+"/level4.xlsx")

# %%
level4
# Out:
#     HDI rank                             Country             Unnamed: 2  \
# 0        160       Tanzania (United Republic of)  LOW HUMAN DEVELOPMENT
# 1        161                            Pakistan  LOW HUMAN DEVELOPMENT
# 2        162                                Togo  LOW HUMAN DEVELOPMENT
# 3        163                               Haiti  LOW HUMAN DEVELOPMENT
# 4        163                             Nigeria  LOW HUMAN DEVELOPMENT
# 5        165                              Rwanda  LOW HUMAN DEVELOPMENT
# 6        166                               Benin  LOW HUMAN DEVELOPMENT
# 7        166                              Uganda  LOW HUMAN DEVELOPMENT
# 8        168                             Lesotho  LOW HUMAN DEVELOPMENT
# 9        169                              Malawi  LOW HUMAN DEVELOPMENT
# 10       170                             Senegal  LOW HUMAN DEVELOPMENT
# 11       171                            Djibouti  LOW HUMAN DEVELOPMENT
# ...

# %%
#Analizamos la tabla y notamos que las cabeceras "Unnamed" no aportan informacion
level4 = level4.loc[:, ~level4.columns.str.startswith('Unnamed')]

# %%
#Verificamos si hay columnas con valores nulos
level4[level4.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [HDI rank, Country, Human Development Index (HDI) , Life expectancy at birth, Expected years of schooling, Mean years of schooling, Gross national income (GNI) per capita, GNI per capita rank minus HDI rank, le]
# Index: []

# %%
#Eliminamos la columna "le" porque no tiene informacion que aporte
level4 = level4.drop('le', axis=1)
level4
# Out:
#     HDI rank                             Country  \
# 0        160       Tanzania (United Republic of)
# 1        161                            Pakistan
# 2        162                                Togo
# 3        163                               Haiti
# 4        163                             Nigeria
# 5        165                              Rwanda
# 6        166                               Benin
# 7        166                              Uganda
# 8        168                             Lesotho
# 9        169                              Malawi
# 10       170                             Senegal
# 11       171                            Djibouti
# 12       172                               Sudan
# 13       173                          Madagascar
# 14       174                              Gambia
# 15       175                            Ethiopia
# 16       176                             Eritrea
# 17       177                       Guinea-Bissau
# ...

# %%
#Le agregamos el año a las columnas en el rango (2,8)
for a in range(2, 8):
    level4.columns.values[a] = level4.columns.values[a] + "2021"
level4
# Out:
#     HDI rank                             Country  \
# 0        160       Tanzania (United Republic of)
# 1        161                            Pakistan
# 2        162                                Togo
# 3        163                               Haiti
# 4        163                             Nigeria
# 5        165                              Rwanda
# 6        166                               Benin
# 7        166                              Uganda
# 8        168                             Lesotho
# 9        169                              Malawi
# 10       170                             Senegal
# 11       171                            Djibouti
# 12       172                               Sudan
# 13       173                          Madagascar
# 14       174                              Gambia
# 15       175                            Ethiopia
# 16       176                             Eritrea
# 17       177                       Guinea-Bissau
# ...

# %%
#Visualizamos el reemplazo los parentesis y espacios por "_"
level4.columns.str.replace('\(\w*\s*\w*\W*\)','',regex=True).str.title().str.replace("\s","_",regex=True)
# Out:
# Index(['Hdi_Rank', 'Country', 'Human_Development_Index__2021',
#        'Life_Expectancy_At_Birth2021', 'Expected_Years_Of_Schooling2021',
#        'Mean_Years_Of_Schooling2021', 'Gross_National_Income__Per_Capita2021',
#        'Gni_Per_Capita_Rank_Minus_Hdi_Rank2021'],
#       dtype='object')

# %%
#Reemplazamos los parentesis y espacios por "_"
level4.columns=level4.columns.str.replace('\(\w*\s*\w*\W*\)','',regex=True).str.title().str.replace("\s","_",regex=True)
level4
# Out:
#     Hdi_Rank                             Country  \
# 0        160       Tanzania (United Republic of)
# 1        161                            Pakistan
# 2        162                                Togo
# 3        163                               Haiti
# 4        163                             Nigeria
# 5        165                              Rwanda
# 6        166                               Benin
# 7        166                              Uganda
# 8        168                             Lesotho
# 9        169                              Malawi
# 10       170                             Senegal
# 11       171                            Djibouti
# 12       172                               Sudan
# 13       173                          Madagascar
# 14       174                              Gambia
# 15       175                            Ethiopia
# 16       176                             Eritrea
# 17       177                       Guinea-Bissau
# ...

# %%
#Hacemos una copia del df y analizamos la existencia de valores nulos
level4_better=level4.copy()
level4_better.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                32 non-null     int64
#  1   Country                                 32 non-null     object
#  2   Human_Development_Index__2021           32 non-null     float64
#  3   Life_Expectancy_At_Birth2021            32 non-null     float64
#  4   Expected_Years_Of_Schooling2021         32 non-null     float64
#  5   Mean_Years_Of_Schooling2021             32 non-null     float64
#  6   Gross_National_Income__Per_Capita2021   32 non-null     float64
#  7   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  32 non-null     int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
#Vamos a transformar todas las columnas en numericos sin afectar a la columna "Country"
level4_clean=level4_better.set_index('Country')
level4_formatted=level4_clean.apply(pd.to_numeric)
level4_formatted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Tanzania (United Republic of) to South Sudan
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Hdi_Rank                                32 non-null     int64
#  1   Human_Development_Index__2021           32 non-null     float64
#  2   Life_Expectancy_At_Birth2021            32 non-null     float64
#  3   Expected_Years_Of_Schooling2021         32 non-null     float64
#  4   Mean_Years_Of_Schooling2021             32 non-null     float64
#  5   Gross_National_Income__Per_Capita2021   32 non-null     float64
#  6   Gni_Per_Capita_Rank_Minus_Hdi_Rank2021  32 non-null     int64
# dtypes: float64(5), int64(2)
# memory usage: 2.0+ KB

# %%
#Devolvemos del indice a la columna "Country"
level4_formatted.reset_index(drop=False,inplace=True)
level4_formatted
# Out:
#                                Country  Hdi_Rank  \
# 0        Tanzania (United Republic of)       160
# 1                             Pakistan       161
# 2                                 Togo       162
# 3                                Haiti       163
# 4                              Nigeria       163
# 5                               Rwanda       165
# 6                                Benin       166
# 7                               Uganda       166
# 8                              Lesotho       168
# 9                               Malawi       169
# 10                             Senegal       170
# 11                            Djibouti       171
# 12                               Sudan       172
# 13                          Madagascar       173
# 14                              Gambia       174
# 15                            Ethiopia       175
# 16                             Eritrea       176
# 17                       Guinea-Bissau       177
# ...

# %%
#Colocamos en mayuscula los elementos de la columna "Country"
level4_formatted['Country']=level4_formatted.Country.str.strip()
level4_formatted['Country']=level4_formatted.Country.str.upper()
level4_formatted
# Out:
#                                Country  Hdi_Rank  \
# 0        TANZANIA (UNITED REPUBLIC OF)       160
# 1                             PAKISTAN       161
# 2                                 TOGO       162
# 3                                HAITI       163
# 4                              NIGERIA       163
# 5                               RWANDA       165
# 6                                BENIN       166
# 7                               UGANDA       166
# 8                              LESOTHO       168
# 9                               MALAWI       169
# 10                             SENEGAL       170
# 11                            DJIBOUTI       171
# 12                               SUDAN       172
# 13                          MADAGASCAR       173
# 14                              GAMBIA       174
# 15                            ETHIOPIA       175
# 16                             ERITREA       176
# 17                       GUINEA-BISSAU       177
# ...

# %%
#Agregamos la columna de indicador de desarrollo
level4_formatted['Development'] = "LOW HUMAN DEVELOPMENT"
level4_formatted
# Out:
#                                Country  Hdi_Rank  \
# 0        TANZANIA (UNITED REPUBLIC OF)       160
# 1                             PAKISTAN       161
# 2                                 TOGO       162
# 3                                HAITI       163
# 4                              NIGERIA       163
# 5                               RWANDA       165
# 6                                BENIN       166
# 7                               UGANDA       166
# 8                              LESOTHO       168
# 9                               MALAWI       169
# 10                             SENEGAL       170
# 11                            DJIBOUTI       171
# 12                               SUDAN       172
# 13                          MADAGASCAR       173
# 14                              GAMBIA       174
# 15                            ETHIOPIA       175
# 16                             ERITREA       176
# 17                       GUINEA-BISSAU       177
# ...

# %%
#Realizamos la concatenacion de las 4 tablas. Coinciden en columnas
result = pd.concat([level1_formatted, level2_formatted, level3_formatted, level4_formatted], ignore_index=True)
result
# Out:
#                       Country  Hdi_Rank  Human_Development_Index__2021  \
# 0                 SWITZERLAND       1.0                          0.962
# 1                      NORWAY       2.0                          0.961
# 2                     ICELAND       3.0                          0.959
# 3      HONG KONG, CHINA (SAR)       4.0                          0.952
# 4                   AUSTRALIA       5.0                          0.951
# ..                        ...       ...                            ...
# 186                   BURUNDI     187.0                          0.426
# 187  CENTRAL AFRICAN REPUBLIC     188.0                          0.404
# 188                     NIGER     189.0                          0.400
# 189                      CHAD     190.0                          0.394
# 190               SOUTH SUDAN     191.0                          0.385
#
#      Life_Expectancy_At_Birth2021  Expected_Years_Of_Schooling2021  \
# ...

# %%
#Cambiamos el tipo de dato de la columna "Hdi_Rank" para mejor apreciacion
result['Hdi_Rank'] = result['Hdi_Rank'].astype(int)
result
# Out:
#                       Country  Hdi_Rank  Human_Development_Index__2021  \
# 0                 SWITZERLAND         1                          0.962
# 1                      NORWAY         2                          0.961
# 2                     ICELAND         3                          0.959
# 3      HONG KONG, CHINA (SAR)         4                          0.952
# 4                   AUSTRALIA         5                          0.951
# ..                        ...       ...                            ...
# 186                   BURUNDI       187                          0.426
# 187  CENTRAL AFRICAN REPUBLIC       188                          0.404
# 188                     NIGER       189                          0.400
# 189                      CHAD       190                          0.394
# 190               SOUTH SUDAN       191                          0.385
#
#      Life_Expectancy_At_Birth2021  Expected_Years_Of_Schooling2021  \
# ...

# %%
#Aplicamos la misma logica para "Hdi_Rank2020" pero pasamos los valores nulos a "0" para comodidades de transformacion
result['Hdi_Rank2020'].fillna(0, inplace=True)
result['Hdi_Rank2020'] = result['Hdi_Rank2020'].astype(int)
result
# Out:
#                       Country  Hdi_Rank  Human_Development_Index__2021  \
# 0                 SWITZERLAND         1                          0.962
# 1                      NORWAY         2                          0.961
# 2                     ICELAND         3                          0.959
# 3      HONG KONG, CHINA (SAR)         4                          0.952
# 4                   AUSTRALIA         5                          0.951
# ..                        ...       ...                            ...
# 186                   BURUNDI       187                          0.426
# 187  CENTRAL AFRICAN REPUBLIC       188                          0.404
# 188                     NIGER       189                          0.400
# 189                      CHAD       190                          0.394
# 190               SOUTH SUDAN       191                          0.385
#
#      Life_Expectancy_At_Birth2021  Expected_Years_Of_Schooling2021  \
# ...

# %% [markdown]
# ## Parte 2

# %%
#Haciendo algunas prueba notamos que no siempre coinciden los cruces de "merge" por eso se realizo un diccionario para hacer los cambios
diccionario_cambios = {
    "HONG KONG, CHINA (SAR)": "CHINA",
    "NETHERLANDS": "NETHERLANDS (THE)",
    "UNITED KINGDOM": "UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)",
    "KOREA (REPUBLIC OF)": "KOREA (THE REPUBLIC OF)",
    "UNITED STATES": "UNITED STATES MINOR OUTLYING ISLANDS (THE)",
    "UNITED ARAB EMIRATES": "UNITED ARAB EMIRATES (THE)",
    "TÜRKIYE": "TURKEY",#
    "RUSSIAN FEDERATION": "RUSSIAN FEDERATION (THE)",
    "BAHAMAS": "BAHAMAS (THE)",
    "DOMINICAN REPUBLIC": "DOMINICAN REPUBLIC (THE)",
    "MOLDOVA (REPUBLIC OF)": "MOLDOVA (THE REPUBLIC OF)",
    "PHILIPPINES": "PHILIPPINES (THE)",
    "LAO PEOPLE'S DEMOCRATIC REPUBLIC": "LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)",
    "ESWATINI (KINGDOM OF)": "ESWATINI",
    "CONGO (DEMOCRATIC REPUBLIC OF THE)": "CONGO (THE DEMOCRATIC REPUBLIC OF THE)",
    "COMOROS": "COMOROS (THE)",
    "CÔTE D'IVOIRE": "C√îTE D'IVOIRE",#
    "TANZANIA (UNITED REPUBLIC OF)": "TANZANIA, THE UNITED REPUBLIC OF",
    "SUDAN": "SUDAN (THE)",
    "GAMBIA": "GAMBIA (THE)",
    "CONGO": "CONGO (THE)",
    "CENTRAL AFRICAN REPUBLIC": "CENTRAL AFRICAN REPUBLIC (THE)",
    "NIGER": "NIGER (THE)"
}

# Aplicar el mapeo al DataFrame
result['Country'] = result['Country'].replace(diccionario_cambios)

# %%
# Direccion que apunta directamente al archivo countryCODES.xlsx
countryCODES_path = append_data_path + "/countryCODES.xlsx"
countryCODES = pd.read_excel(countryCODES_path)

# %%
countryCODES
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# ...

# %%
#Realizamos el cruce en base a la columna "Country"
merged_df = pd.merge(result, countryCODES, on='Country', how='inner')
merged_df
# Out:
#                             Country  Hdi_Rank  Human_Development_Index__2021  \
# 0                       SWITZERLAND         1                          0.962
# 1                            NORWAY         2                          0.961
# 2                           ICELAND         3                          0.959
# 3                             CHINA         4                          0.952
# 4                             CHINA        79                          0.768
# ..                              ...       ...                            ...
# 167                         BURUNDI       187                          0.426
# 168  CENTRAL AFRICAN REPUBLIC (THE)       188                          0.404
# 169                     NIGER (THE)       189                          0.400
# 170                            CHAD       190                          0.394
# 171                     SOUTH SUDAN       191                          0.385
#
# ...

# %%
# Notamos que existe "China" tanto como pais como distrito distrito financiero en el merge y ahora le devolveremos su nombre anterior
condicion = (merged_df['Country'] == 'CHINA') & (merged_df['Hdi_Rank'] == 4)

# Cambiar el valor en la celda correspondiente
merged_df.loc[condicion, 'Country'] = 'HONG KONG, CHINA (SAR)' #Notamos que este es el distrito financiero
merged_df
# Out:
#                             Country  Hdi_Rank  Human_Development_Index__2021  \
# 0                       SWITZERLAND         1                          0.962
# 1                            NORWAY         2                          0.961
# 2                           ICELAND         3                          0.959
# 3            HONG KONG, CHINA (SAR)         4                          0.952
# 4                             CHINA        79                          0.768
# ..                              ...       ...                            ...
# 167                         BURUNDI       187                          0.426
# 168  CENTRAL AFRICAN REPUBLIC (THE)       188                          0.404
# 169                     NIGER (THE)       189                          0.400
# 170                            CHAD       190                          0.394
# 171                     SOUTH SUDAN       191                          0.385
#
# ...

# %% [markdown]
# ## Parte 3

# %%
# Direccion que apunta directamente al archivo countryCODES.xlsx
fallecidos_path = append_data_path + "/fallecidosCOVID.csv"

# %%
#Leemos el archivo CSV en Pandas
fallecidos_df = pd.read_csv(fallecidos_path,sep=";")

# %%
fallecidos_df
# Out:
#         FECHA_CORTE  FECHA_FALLECIMIENTO  EDAD_DECLARADA       SEXO  \
# 0          20240317             20220219              63  MASCULINO
# 1          20240317             20210529              74  MASCULINO
# 2          20240317             20210623              72   FEMENINO
# 3          20240317             20210824              85  MASCULINO
# 4          20240317             20210627              46  MASCULINO
# ...             ...                  ...             ...        ...
# 220913     20240317             20200809              77  MASCULINO
# 220914     20240317             20201028              81  MASCULINO
# 220915     20240317             20200515              68   FEMENINO
# 220916     20240317             20210414              66   FEMENINO
# 220917     20240317             20200819              61  MASCULINO
#
#                             CLASIFICACION_DEF DEPARTAMENTO PROVINCIA  \
# 0                         Criterio virológico       TUMBES    TUMBES
# ...

# %%
# Convertir FECHA_FALLECIMIENTO a datetime
fallecidos_df['FECHA_FALLECIMIENTO'] = pd.to_datetime(fallecidos_df['FECHA_FALLECIMIENTO'], format='%Y%m%d')

# %%
# Agrupamos por mes y año, y contamos los fallecidos
fallecidos_df['Año-Mes'] = fallecidos_df['FECHA_FALLECIMIENTO'].dt.to_period('M')  # Crear una nueva columna para agrupar por mes y año
reporte_mensual = fallecidos_df.groupby('Año-Mes').size().reset_index(name='Fallecidos')
reporte_mensual
# Out:
#     Año-Mes  Fallecidos
# 0   2020-03         181
# 1   2020-04        5134
# 2   2020-05       16363
# 3   2020-06       17462
# 4   2020-07       18501
# 5   2020-08       17668
# 6   2020-09        8437
# 7   2020-10        4471
# 8   2020-11        3229
# 9   2020-12        3885
# 10  2021-01       11175
# 11  2021-02       18645
# 12  2021-03       20691
# 13  2021-04       23110
# 14  2021-05       16692
# 15  2021-06        7722
# 16  2021-07        3481
# 17  2021-08        1850
# 18  2021-09        1140
# 19  2021-10        1066
# 20  2021-11        1107
# 21  2021-12        1283
# 22  2022-01        3562
# 23  2022-02        3503
# 24  2022-03        1299
# 25  2022-04         741
# 26  2022-05         625
# 27  2022-06         542
# 28  2022-07        1025
# 29  2022-08        1429
# 30  2022-09         892
# 31  2022-10         429
# 32  2022-11         272
# 33  2022-12         423
# 34  2023-01         371
# 35  2023-02         287
# 36  2023-03         295
# ...

# %% [markdown]
# ## Parte 4

# %%
# Generar tabla pivote para hacer un reporte de fallecidos por mes con el tipo de muerte en columnas separadas
reporte_pivot = pd.pivot_table(fallecidos_df, 
                               index='Año-Mes', 
                               columns='CLASIFICACION_DEF', 
                               values='FECHA_CORTE', 
                               aggfunc='count', 
                               fill_value=0)

# %%
reporte_pivot
# Out:
# CLASIFICACION_DEF  Criterio SINADEF  Criterio clínico  \
# Año-Mes
# 2020-03                          35                52
# 2020-04                        1793               541
# 2020-05                        6826              1152
# 2020-06                        5722               670
# 2020-07                        5012               609
# 2020-08                        4589               611
# 2020-09                        1984               475
# 2020-10                        1091               463
# 2020-11                         704               462
# 2020-12                         802               547
# 2021-01                        2190               514
# 2021-02                        4993               501
# 2021-03                        6100               525
# 2021-04                        7450               748
# 2021-05                        5225               628
# 2021-06                        2723               116
# ...
